# %%
# Importando as bibliotecas necessárias 
import pandas as pd
import missingno
import numpy as np

# %%
# Abrindo o arquivo
file = 'country_vaccinations.csv'
df = pd.read_csv (file)

# %%
# Lendo as primeiras 10  linhas da tabela
df.head(10)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
# 6  Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG  2021-03-01                 NaN                NaN
# 8  Afghanistan      AFG  2021-03-02                 NaN                NaN
# 9  Afghanistan      AFG  2021-03-03                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
# 5                      NaN                     NaN              1367.0
# 6                      NaN                     NaN              1367.0
# 7                      NaN                     NaN              1580.0
# 8                      NaN                     NaN              1794.0
# 9                      NaN                     NaN              2008.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                            0.02                           0.02
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
# 5                                  NaN                            34.0
# 6                                  NaN                            34.0
# 7                                  NaN                            40.0
# 8                                  NaN                            45.0
# 9                                  NaN                            50.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 5  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 6  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 7  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 8  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 9  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/
# 5  World Health Organization  https://covid19.who.int/
# 6  World Health Organization  https://covid19.who.int/
# 7  World Health Organization  https://covid19.who.int/
# 8  World Health Organization  https://covid19.who.int/
# 9  World Health Organization  https://covid19.who.int/

# %%
# Lendo os últimas 10  linhas da tabela

df.tail(10)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 81966  Zimbabwe      ZWE  2022-02-26           7876942.0          4357938.0
# 81967  Zimbabwe      ZWE  2022-02-27           7882244.0          4359872.0
# 81968  Zimbabwe      ZWE  2022-02-28           7890951.0          4362150.0
# 81969  Zimbabwe      ZWE  2022-03-01           7901360.0          4365856.0
# 81970  Zimbabwe      ZWE  2022-03-02           7910740.0          4368726.0
# 81971  Zimbabwe      ZWE  2022-03-03           7921113.0          4372925.0
# 81972  Zimbabwe      ZWE  2022-03-04           7930621.0          4374896.0
# 81973  Zimbabwe      ZWE  2022-03-05           7936145.0          4377373.0
# 81974  Zimbabwe      ZWE  2022-03-06           7938362.0          4378029.0
# 81975  Zimbabwe      ZWE  2022-03-07           7943325.0          4379875.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 81966                3390880.0                  6543.0              8008.0
# 81967                3392578.0                  5302.0              8336.0
# 81968                3396655.0                  8707.0              8836.0
# 81969                3399915.0                 10409.0              9291.0
# 81970                3402434.0                  9380.0              9061.0
# 81971                3406482.0                 10373.0              8903.0
# 81972                3408609.0                  9508.0              8603.0
# 81973                3410340.0                  5524.0              8458.0
# 81974                3410960.0                  2217.0              8017.0
# 81975                3412556.0                  4963.0              7482.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 81966                           52.19                          28.88
# 81967                           52.23                          28.89
# 81968                           52.29                          28.90
# 81969                           52.35                          28.93
# 81970                           52.42                          28.95
# 81971                           52.48                          28.97
# 81972                           52.55                          28.99
# 81973                           52.58                          29.00
# 81974                           52.60                          29.01
# 81975                           52.63                          29.02
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 81966                                22.47                           531.0
# 81967                                22.48                           552.0
# 81968                                22.51                           585.0
# 81969                                22.53                           616.0
# 81970                                22.54                           600.0
# 81971                                22.57                           590.0
# 81972                                22.59                           570.0
# 81973                                22.60                           560.0
# 81974                                22.60                           531.0
# 81975                                22.61                           496.0
#
#                                                 vaccines         source_name  \
# 81966  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 81967  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 81968  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 81969  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 81970  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 81971  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 81972  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 81973  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 81974  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 81975  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
#
#                                           source_website
# 81966  https://www.arcgis.com/home/webmap/viewer.html...
# 81967  https://www.arcgis.com/home/webmap/viewer.html...
# 81968  https://www.arcgis.com/home/webmap/viewer.html...
# 81969  https://www.arcgis.com/home/webmap/viewer.html...
# 81970  https://www.arcgis.com/home/webmap/viewer.html...
# 81971  https://www.arcgis.com/home/webmap/viewer.html...
# 81972  https://www.arcgis.com/home/webmap/viewer.html...
# 81973  https://www.arcgis.com/home/webmap/viewer.html...
# 81974  https://www.arcgis.com/home/webmap/viewer.html...
# 81975  https://www.arcgis.com/home/webmap/viewer.html...

# %%
#Observando se há valores faltantes de caráter observacional, onde há o menor N amostral por coluna observa-se a ausência de amostras
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81976 entries, 0 to 81975
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              81976 non-null  object
#  1   iso_code                             81976 non-null  object
#  2   date                                 81976 non-null  object
#  3   total_vaccinations                   41873 non-null  float64
#  4   people_vaccinated                    39638 non-null  float64
#  5   people_fully_vaccinated              37119 non-null  float64
#  6   daily_vaccinations_raw               34033 non-null  float64
#  7   daily_vaccinations                   81697 non-null  float64
#  8   total_vaccinations_per_hundred       41873 non-null  float64
#  9   people_vaccinated_per_hundred        39638 non-null  float64
#  10  people_fully_vaccinated_per_hundred  37119 non-null  float64
#  11  daily_vaccinations_per_million       81697 non-null  float64
#  12  vaccines                             81976 non-null  object
#  13  source_name                          81976 non-null  object
#  14  source_website                       81976 non-null  object
# dtypes: float64(9), object(6)
# memory usage: 9.4+ MB

# %%
# De maneira objetiva esse comando nos mostra as colunas que há valores faltantes , sendo  FALSE para as COLUNAS que NÃO tem valores faltantes e TRUE para os que TEM valores faltantes
df.isna().any()
# Out:
# country                                False
# iso_code                               False
# date                                   False
# total_vaccinations                      True
# people_vaccinated                       True
# people_fully_vaccinated                 True
# daily_vaccinations_raw                  True
# daily_vaccinations                      True
# total_vaccinations_per_hundred          True
# people_vaccinated_per_hundred           True
# people_fully_vaccinated_per_hundred     True
# daily_vaccinations_per_million          True
# vaccines                               False
# source_name                            False
# source_website                         False
# dtype: bool

# %%
# Observando por meio de  de uma interface gráfica de maneira precisa onde  há os valores faltantes
#Obs: Os espaços em branco correspondem aos valores faltantes
missingno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
# É um gráfico de barras ilustra os valores totais de todas as colunas
missingno.bar(df)
# Out:
# <AxesSubplot:>

# %%
# Aqui ele vai me retornar todas as linhas que possui pelo menos um valor faltante (isna().any)
df[df.isna().any(axis = 1)]
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 81805     Zimbabwe      ZWE  2021-09-18           4982928.0
# 81865     Zimbabwe      ZWE  2021-11-17                 NaN
# 81866     Zimbabwe      ZWE  2021-11-18           6310431.0
# 81908     Zimbabwe      ZWE  2021-12-30                 NaN
# 81909     Zimbabwe      ZWE  2021-12-31           7264791.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 81805          2931177.0                2051751.0                     NaN
# 81865                NaN                      NaN                     NaN
# 81866          3583256.0                2727175.0                     NaN
# 81908                NaN                      NaN                     NaN
# 81909          4124378.0                3135168.0                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 81805             40514.0                           33.02
# 81865             27152.0                             NaN
# 81866             29822.0                           41.81
# 81908              9105.0                             NaN
# 81909              9145.0                           48.14
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 81805                          19.42                                13.59
# 81865                            NaN                                  NaN
# 81866                          23.74                                18.07
# 81908                            NaN                                  NaN
# 81909                          27.33                                20.77
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 1                                34.0
# 2                                34.0
# 3                                34.0
# 4                                34.0
# ...                               ...
# 81805                          2684.0
# 81865                          1799.0
# 81866                          1976.0
# 81908                           603.0
# 81909                           606.0
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 81805  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81865  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81866  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81908  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81909  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 81805         Ministry of Health
# 81865         Ministry of Health
# 81866         Ministry of Health
# 81908         Ministry of Health
# 81909         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 81805  https://www.arcgis.com/home/webmap/viewer.html...
# 81865  https://www.arcgis.com/home/webmap/viewer.html...
# 81866  https://www.arcgis.com/home/webmap/viewer.html...
# 81908  https://www.arcgis.com/home/webmap/viewer.html...
# 81909  https://www.arcgis.com/home/webmap/viewer.html...
#
# [52357 rows x 15 columns]

# %%
# Me retorna linhas  que não tem nenhum valor faltante, observe que agora = notna(). all
# em suma elimina os n/as

df[df.notna().all(axis = 1)]
# Out:
#            country iso_code        date  total_vaccinations  \
# 94     Afghanistan      AFG  2021-05-27            593313.0
# 101    Afghanistan      AFG  2021-06-03            630305.0
# 339    Afghanistan      AFG  2022-01-27           5081064.0
# 417        Albania      ALB  2021-02-18              3049.0
# 499        Albania      ALB  2021-05-11            622507.0
# ...            ...      ...         ...                 ...
# 81971     Zimbabwe      ZWE  2022-03-03           7921113.0
# 81972     Zimbabwe      ZWE  2022-03-04           7930621.0
# 81973     Zimbabwe      ZWE  2022-03-05           7936145.0
# 81974     Zimbabwe      ZWE  2022-03-06           7938362.0
# 81975     Zimbabwe      ZWE  2022-03-07           7943325.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 94              479574.0                 113739.0                  2859.0
# 101             481800.0                 148505.0                  4015.0
# 339            4517380.0                3868832.0                  6868.0
# 417               2438.0                    611.0                  1348.0
# 499             440921.0                 181586.0                  9548.0
# ...                  ...                      ...                     ...
# 81971          4372925.0                3406482.0                 10373.0
# 81972          4374896.0                3408609.0                  9508.0
# 81973          4377373.0                3410340.0                  5524.0
# 81974          4378029.0                3410960.0                  2217.0
# 81975          4379875.0                3412556.0                  4963.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 94                 6487.0                            1.49
# 101                5285.0                            1.58
# 339                9802.0                           12.76
# 417                 254.0                            0.11
# 499               12160.0                           21.67
# ...                   ...                             ...
# 81971              8903.0                           52.48
# 81972              8603.0                           52.55
# 81973              8458.0                           52.58
# 81974              8017.0                           52.60
# 81975              7482.0                           52.63
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 94                              1.20                                 0.29
# 101                             1.21                                 0.37
# 339                            11.34                                 9.71
# 417                             0.08                                 0.02
# 499                            15.35                                 6.32
# ...                              ...                                  ...
# 81971                          28.97                                22.57
# 81972                          28.99                                22.59
# 81973                          29.00                                22.60
# 81974                          29.01                                22.60
# 81975                          29.02                                22.61
#
#        daily_vaccinations_per_million  \
# 94                              163.0
# 101                             133.0
# 339                             246.0
# 417                              88.0
# 499                            4233.0
# ...                               ...
# 81971                           590.0
# 81972                           570.0
# 81973                           560.0
# 81974                           531.0
# 81975                           496.0
#
#                                                 vaccines  \
# 94     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 101    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 339    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 417    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 499    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# ...                                                  ...
# 81971  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81972  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81973  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81974  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81975  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 94     World Health Organization
# 101    World Health Organization
# 339    World Health Organization
# 417           Ministry of Health
# 499           Ministry of Health
# ...                          ...
# 81971         Ministry of Health
# 81972         Ministry of Health
# 81973         Ministry of Health
# 81974         Ministry of Health
# 81975         Ministry of Health
#
#                                           source_website
# 94                              https://covid19.who.int/
# 101                             https://covid19.who.int/
# 339                             https://covid19.who.int/
# 417    https://shendetesia.gov.al/vaksinimi-anticovid...
# 499    https://shendetesia.gov.al/vaksinimi-anticovid...
# ...                                                  ...
# 81971  https://www.arcgis.com/home/webmap/viewer.html...
# 81972  https://www.arcgis.com/home/webmap/viewer.html...
# 81973  https://www.arcgis.com/home/webmap/viewer.html...
# 81974  https://www.arcgis.com/home/webmap/viewer.html...
# 81975  https://www.arcgis.com/home/webmap/viewer.html...
#
# [29619 rows x 15 columns]

# %%
# Aqui com o comando reset_index, eu reseto os valores naturais da ordem do data frame e mantenho apenas as amostras que estão presentes em todas as linhas e colunas
# OBS: Deixei de lado/joguei  fora todos os dados faltantes

df2 = df[df.notna().all(axis = 1)]. reset_index(drop = True)

# %%
# Observe que todas as colunas possuem a mesma quantidade de amostras 
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29619 entries, 0 to 29618
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              29619 non-null  object
#  1   iso_code                             29619 non-null  object
#  2   date                                 29619 non-null  object
#  3   total_vaccinations                   29619 non-null  float64
#  4   people_vaccinated                    29619 non-null  float64
#  5   people_fully_vaccinated              29619 non-null  float64
#  6   daily_vaccinations_raw               29619 non-null  float64
#  7   daily_vaccinations                   29619 non-null  float64
#  8   total_vaccinations_per_hundred       29619 non-null  float64
#  9   people_vaccinated_per_hundred        29619 non-null  float64
#  10  people_fully_vaccinated_per_hundred  29619 non-null  float64
#  11  daily_vaccinations_per_million       29619 non-null  float64
#  12  vaccines                             29619 non-null  object
#  13  source_name                          29619 non-null  object
#  14  source_website                       29619 non-null  object
# dtypes: float64(9), object(6)
# memory usage: 3.4+ MB

# %%
# Observando graficamente (2), note que não há lacunas, tudo preenchidos sem espaços em branco
missingno.matrix(df2)
# Out:
# <AxesSubplot:>

# %%
# Aqui calculamos a porcentagem por meio do laço de repetição (for) dos valores faltantes.
for col in df.columns:
    perc = np.mean(df[col].isna())
    print (f'{col}: {round(perc*100)} %')
# Out:
# country: 0 %
# iso_code: 0 %
# date: 0 %
# total_vaccinations: 49 %
# people_vaccinated: 52 %
# people_fully_vaccinated: 55 %
# daily_vaccinations_raw: 58 %
# daily_vaccinations: 0 %
# total_vaccinations_per_hundred: 49 %
# people_vaccinated_per_hundred: 52 %
# people_fully_vaccinated_per_hundred: 55 %
# daily_vaccinations_per_million: 0 %
# vaccines: 0 %
# source_name: 0 %
# source_website: 0 %

# %%
# Selecionei a coluna total vacinations e dentro dela só quero os que são menores ou iguais a dez mil

dff = df[df['total_vaccinations'] <=10000]
dff.info()

# %%
# Esta função é análoga a de cima, a partir de então irei usa-la.

dff2 = df.query('total_vaccinations <=10000')
dff2
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 6      Afghanistan      AFG  2021-02-28              8200.0
# 378        Albania      ALB  2021-01-10                 0.0
# 380        Albania      ALB  2021-01-12               128.0
# 381        Albania      ALB  2021-01-13               188.0
# ...            ...      ...         ...                 ...
# 81274       Zambia      ZMB  2021-04-21              9006.0
# 81593     Zimbabwe      ZWE  2021-02-18                39.0
# 81596     Zimbabwe      ZWE  2021-02-21              1314.0
# 81598     Zimbabwe      ZWE  2021-02-23              4041.0
# 81599     Zimbabwe      ZWE  2021-02-24              6115.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 6                 8200.0                      NaN                     NaN
# 378                  0.0                      NaN                     NaN
# 380                128.0                      NaN                     NaN
# 381                188.0                      NaN                    60.0
# ...                  ...                      ...                     ...
# 81274             9006.0                      NaN                  5615.0
# 81593               39.0                      NaN                     NaN
# 81596             1314.0                      NaN                     NaN
# 81598             4041.0                      NaN                     NaN
# 81599             6115.0                      NaN                  2074.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 6                  1367.0                            0.02
# 378                   NaN                            0.00
# 380                  64.0                            0.00
# 381                  63.0                            0.01
# ...                   ...                             ...
# 81274              1287.0                            0.05
# 81593                 NaN                            0.00
# 81596               425.0                            0.01
# 81598               800.0                            0.03
# 81599              1013.0                            0.04
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 6                               0.02                                  NaN
# 378                             0.00                                  NaN
# 380                             0.00                                  NaN
# 381                             0.01                                  NaN
# ...                              ...                                  ...
# 81274                           0.05                                  NaN
# 81593                           0.00                                  NaN
# 81596                           0.01                                  NaN
# 81598                           0.03                                  NaN
# 81599                           0.04                                  NaN
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 6                                34.0
# 378                               NaN
# 380                              22.0
# 381                              22.0
# ...                               ...
# 81274                            68.0
# 81593                             NaN
# 81596                            28.0
# 81598                            53.0
# 81599                            67.0
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 6      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 378    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 380    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 381    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# ...                                                  ...
# 81274  Johnson&Johnson, Oxford/AstraZeneca, Sinopharm...
# 81593  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81596  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81598  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81599  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 0      World Health Organization
# 6      World Health Organization
# 378           Ministry of Health
# 380           Ministry of Health
# 381           Ministry of Health
# ...                          ...
# 81274       Government of Zambia
# 81593         Ministry of Health
# 81596         Ministry of Health
# 81598         Ministry of Health
# 81599         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 6                               https://covid19.who.int/
# 378    https://shendetesia.gov.al/vaksinimi-anticovid...
# 380    https://shendetesia.gov.al/vaksinimi-anticovid...
# 381    https://shendetesia.gov.al/vaksinimi-anticovid...
# ...                                                  ...
# 81274  https://rtc-planning.maps.arcgis.com/apps/dash...
# 81593  https://www.arcgis.com/home/webmap/viewer.html...
# 81596  https://www.arcgis.com/home/webmap/viewer.html...
# 81598  https://www.arcgis.com/home/webmap/viewer.html...
# 81599  https://www.arcgis.com/home/webmap/viewer.html...
#
# [1062 rows x 15 columns]

# %%
# Na coluna country eu selecionei o Brazil e na coluna people vaccinated os que estão acima de 100000 (cem mil)
dff3 = df.query('country == "Brazil" & people_vaccinated >= 100000')
dff3
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 10099  Brazil      BRA  2021-01-20            105824.0           105824.0
# 10100  Brazil      BRA  2021-01-21            193699.0           193699.0
# 10101  Brazil      BRA  2021-01-22            462269.0           462269.0
# 10102  Brazil      BRA  2021-01-23            573268.0           573268.0
# 10103  Brazil      BRA  2021-01-24            613954.0           613954.0
# ...       ...      ...         ...                 ...                ...
# 10506  Brazil      BRA  2022-03-03         394111796.0        177987744.0
# 10507  Brazil      BRA  2022-03-04         394812859.0        178113009.0
# 10508  Brazil      BRA  2022-03-05         395464826.0        178203894.0
# 10509  Brazil      BRA  2022-03-06         395658972.0        178245534.0
# 10510  Brazil      BRA  2022-03-07         396537303.0        178366451.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 10099                      NaN                 92297.0             35237.0
# 10100                      NaN                 87875.0             48397.0
# 10101                      NaN                268570.0             92431.0
# 10102                      NaN                110999.0             95526.0
# 10103                      NaN                 40686.0             87692.0
# ...                        ...                     ...                 ...
# 10506              155380086.0                     NaN            623346.0
# 10507              155569412.0                701063.0            508531.0
# 10508              155711613.0                651967.0            525686.0
# 10509              155740455.0                194146.0            526934.0
# 10510              155930535.0                878331.0            539096.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 10099                            0.05                           0.05
# 10100                            0.09                           0.09
# 10101                            0.22                           0.22
# 10102                            0.27                           0.27
# 10103                            0.29                           0.29
# ...                               ...                            ...
# 10506                          184.17                          83.17
# 10507                          184.50                          83.23
# 10508                          184.80                          83.28
# 10509                          184.89                          83.29
# 10510                          185.30                          83.35
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 10099                                  NaN                           165.0
# 10100                                  NaN                           226.0
# 10101                                  NaN                           432.0
# 10102                                  NaN                           446.0
# 10103                                  NaN                           410.0
# ...                                    ...                             ...
# 10506                                72.61                          2913.0
# 10507                                72.70                          2376.0
# 10508                                72.76                          2457.0
# 10509                                72.78                          2462.0
# 10510                                72.87                          2519.0
#
#                                                 vaccines  \
# 10099  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 10100  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 10101  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 10102  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 10103  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 10506  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 10507  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 10508  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 10509  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 10510  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                                            source_name  \
# 10099  State governments via coronavirusbra1.github.io
# 10100  State governments via coronavirusbra1.github.io
# 10101  State governments via coronavirusbra1.github.io
# 10102  State governments via coronavirusbra1.github.io
# 10103  State governments via coronavirusbra1.github.io
# ...                                                ...
# 10506  State governments via coronavirusbra1.github.io
# 10507  State governments via coronavirusbra1.github.io
# 10508  State governments via coronavirusbra1.github.io
# 10509  State governments via coronavirusbra1.github.io
# 10510  State governments via coronavirusbra1.github.io
#
#                           source_website
# 10099  https://coronavirusbra1.github.io
# 10100  https://coronavirusbra1.github.io
# 10101  https://coronavirusbra1.github.io
# 10102  https://coronavirusbra1.github.io
# 10103  https://coronavirusbra1.github.io
# ...                                  ...
# 10506  https://coronavirusbra1.github.io
# 10507  https://coronavirusbra1.github.io
# 10508  https://coronavirusbra1.github.io
# 10509  https://coronavirusbra1.github.io
# 10510  https://coronavirusbra1.github.io
#
# [401 rows x 15 columns]

# %%
# OU no formato de  | , aqui ele irá selecionar todos as linhas que possuem mais de 1 mihção na coluna total vaccinations ou as linhas que tem mais de cem mil na coluna people fully vaccination
dff4 = df.query ('total_vaccinations > 1e6 | people_fully_vaccinated > 1e5')
dff4
# Out:
#            country iso_code        date  total_vaccinations  \
# 93     Afghanistan      AFG  2021-05-26            590454.0
# 94     Afghanistan      AFG  2021-05-27            593313.0
# 97     Afghanistan      AFG  2021-05-30            600152.0
# 100    Afghanistan      AFG  2021-06-02            626290.0
# 101    Afghanistan      AFG  2021-06-03            630305.0
# ...            ...      ...         ...                 ...
# 81971     Zimbabwe      ZWE  2022-03-03           7921113.0
# 81972     Zimbabwe      ZWE  2022-03-04           7930621.0
# 81973     Zimbabwe      ZWE  2022-03-05           7936145.0
# 81974     Zimbabwe      ZWE  2022-03-06           7938362.0
# 81975     Zimbabwe      ZWE  2022-03-07           7943325.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 93              479372.0                 111082.0                     NaN
# 94              479574.0                 113739.0                  2859.0
# 97              480226.0                 119926.0                     NaN
# 100             481690.0                 144600.0                     NaN
# 101             481800.0                 148505.0                  4015.0
# ...                  ...                      ...                     ...
# 81971          4372925.0                3406482.0                 10373.0
# 81972          4374896.0                3408609.0                  9508.0
# 81973          4377373.0                3410340.0                  5524.0
# 81974          4378029.0                3410960.0                  2217.0
# 81975          4379875.0                3412556.0                  4963.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 93                 6768.0                            1.48
# 94                 6487.0                            1.49
# 97                 4746.0                            1.51
# 100                5119.0                            1.57
# 101                5285.0                            1.58
# ...                   ...                             ...
# 81971              8903.0                           52.48
# 81972              8603.0                           52.55
# 81973              8458.0                           52.58
# 81974              8017.0                           52.60
# 81975              7482.0                           52.63
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 93                              1.20                                 0.28
# 94                              1.20                                 0.29
# 97                              1.21                                 0.30
# 100                             1.21                                 0.36
# 101                             1.21                                 0.37
# ...                              ...                                  ...
# 81971                          28.97                                22.57
# 81972                          28.99                                22.59
# 81973                          29.00                                22.60
# 81974                          29.01                                22.60
# 81975                          29.02                                22.61
#
#        daily_vaccinations_per_million  \
# 93                              170.0
# 94                              163.0
# 97                              119.0
# 100                             129.0
# 101                             133.0
# ...                               ...
# 81971                           590.0
# 81972                           570.0
# 81973                           560.0
# 81974                           531.0
# 81975                           496.0
#
#                                                 vaccines  \
# 93     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 94     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 97     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 100    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 101    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 81971  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81972  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81973  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81974  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81975  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 93     World Health Organization
# 94     World Health Organization
# 97     World Health Organization
# 100    World Health Organization
# 101    World Health Organization
# ...                          ...
# 81971         Ministry of Health
# 81972         Ministry of Health
# 81973         Ministry of Health
# 81974         Ministry of Health
# 81975         Ministry of Health
#
#                                           source_website
# 93                              https://covid19.who.int/
# 94                              https://covid19.who.int/
# 97                              https://covid19.who.int/
# 100                             https://covid19.who.int/
# 101                             https://covid19.who.int/
# ...                                                  ...
# 81971  https://www.arcgis.com/home/webmap/viewer.html...
# 81972  https://www.arcgis.com/home/webmap/viewer.html...
# 81973  https://www.arcgis.com/home/webmap/viewer.html...
# 81974  https://www.arcgis.com/home/webmap/viewer.html...
# 81975  https://www.arcgis.com/home/webmap/viewer.html...
#
# [32169 rows x 15 columns]

# %%
# Filtrando data específica e nação
df.query('date >= " 2021-06-01" & country == "Afghanistan"')

# %%
# FILTRANDO INTERVALOS DE TEMPO entre dia 01 e dia 31
df.query ('date in ["2021-05-01", "2021-05-31"]')

# %%
# ELIMINANDO as colunas que possuem  N/AS nas colunas
dff5= df.dropna(axis=1)
dff5
# Out:
#            country iso_code        date  \
# 0      Afghanistan      AFG  2021-02-22
# 1      Afghanistan      AFG  2021-02-23
# 2      Afghanistan      AFG  2021-02-24
# 3      Afghanistan      AFG  2021-02-25
# 4      Afghanistan      AFG  2021-02-26
# ...            ...      ...         ...
# 81971     Zimbabwe      ZWE  2022-03-03
# 81972     Zimbabwe      ZWE  2022-03-04
# 81973     Zimbabwe      ZWE  2022-03-05
# 81974     Zimbabwe      ZWE  2022-03-06
# 81975     Zimbabwe      ZWE  2022-03-07
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 81971  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81972  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81973  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81974  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 81975  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 81971         Ministry of Health
# 81972         Ministry of Health
# 81973         Ministry of Health
# 81974         Ministry of Health
# 81975         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 81971  https://www.arcgis.com/home/webmap/viewer.html...
# 81972  https://www.arcgis.com/home/webmap/viewer.html...
# 81973  https://www.arcgis.com/home/webmap/viewer.html...
# 81974  https://www.arcgis.com/home/webmap/viewer.html...
# 81975  https://www.arcgis.com/home/webmap/viewer.html...
#
# [81976 rows x 6 columns]

# %%
# Substituindo N/AS pela mediana
#Calculado a mediana
dfm= df.median()
dfm
# Out:
# C:\Users\cleto\AppData\Local\Temp/ipykernel_2736/3271806475.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfm= df.median()
# total_vaccinations                     3351838.00
# people_vaccinated                      2056975.50
# people_fully_vaccinated                1585259.00
# daily_vaccinations_raw                   25711.00
# daily_vaccinations                        7660.00
# total_vaccinations_per_hundred              62.92
# people_vaccinated_per_hundred               39.30
# people_fully_vaccinated_per_hundred         29.43
# daily_vaccinations_per_million            2161.00
# dtype: float64

# %%
# listando os valores
mediana = df.median().values
mediana
# Out:
# C:\Users\cleto\AppData\Local\Temp/ipykernel_2736/3086688120.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mediana = df.median().values
# array([3.3518380e+06, 2.0569755e+06, 1.5852590e+06, 2.5711000e+04,
#        7.6600000e+03, 6.2920000e+01, 3.9300000e+01, 2.9430000e+01,
#        2.1610000e+03])

# %%
#Selecionando as colunas com valores numéricos
cols = ['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'daily_vaccinations_raw', 'daily_vaccinations', 'total_vaccinations_per_hundred','people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred','daily_vaccinations_per_million']
len(cols)
# Out:
# 9

# %%
#substituindo os valores faltantes pela mediana de cada coluna
for i in range(len(mediana)):
    df[cols[i]] = df[cols[i]].fillna(mediana[i])

# %%
#Conferindo, todos as colunas possuem a mesma quantidade de 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81976 entries, 0 to 81975
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              81976 non-null  object
#  1   iso_code                             81976 non-null  object
#  2   date                                 81976 non-null  object
#  3   total_vaccinations                   81976 non-null  float64
#  4   people_vaccinated                    81976 non-null  float64
#  5   people_fully_vaccinated              81976 non-null  float64
#  6   daily_vaccinations_raw               81976 non-null  float64
#  7   daily_vaccinations                   81976 non-null  float64
#  8   total_vaccinations_per_hundred       81976 non-null  float64
#  9   people_vaccinated_per_hundred        81976 non-null  float64
#  10  people_fully_vaccinated_per_hundred  81976 non-null  float64
#  11  daily_vaccinations_per_million       81976 non-null  float64
#  12  vaccines                             81976 non-null  object
#  13  source_name                          81976 non-null  object
#  14  source_website                       81976 non-null  object
# dtypes: float64(9), object(6)
# memory usage: 9.4+ MB

# %%
# Observando graficamente
missingno.matrix(df)
# Out:
# <AxesSubplot:>
